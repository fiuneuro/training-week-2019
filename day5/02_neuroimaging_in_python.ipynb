# %% [markdown]
# # Working with neuroimaging data in Python
# Using pybids, nibabel, and nilearn.

# %%
from bids import BIDSLayout

# %%
import nibabel as nib

# %%
import nilearn as nl
from nilearn import masking
